# %% [markdown]
# <h1> Guided lab: Regression Models with Keras</h1>
#
# Objective for this Notebook
#
# - How to use the Tensorflow API, Keras, to build a regression model.
# - Download and Clean dataset
# - Build a Neural Network
# - Train and Test the Network

# %% [markdown]
# ## Table of Contents
#
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#
# <font size = 3>
#
# 1. <a href="#item31">Download and Clean Dataset</a>
# 2. <a href="#item32">Import Keras</a>
# 3. <a href="#item33">Build a Neural Network</a>
# 4. <a href="#item34">Train and Test the Network</a>
#
# </font>
# </div>

# %% [markdown]
# <a id="item31"></a>

# %% [markdown]
# ## Download and Clean Dataset

# %% [markdown]
# Let's start by importing the <em>pandas</em> and the Numpy libraries.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# We will be playing around with the same dataset that we used in the videos.
#
# <strong>The dataset is about the compressive strength of different samples of concrete based on the volumes of the different ingredients that were used to make them. Ingredients include:</strong>
#
# <strong>1. Cement</strong>
#
# <strong>2. Blast Furnace Slag</strong>
#
# <strong>3. Fly Ash</strong>
#
# <strong>4. Water</strong>
#
# <strong>5. Superplasticizer</strong>
#
# <strong>6. Coarse Aggregate</strong>
#
# <strong>7. Fine Aggregate</strong>

# %% [markdown]
# Let's download the data and read it into a <em>pandas</em> dataframe.

# %%
concrete_data = pd.read_csv('https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0101EN/labs/data/concrete_data.csv')
concrete_data.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age  Strength
# 0            1040.0           676.0   28     79.99
# 1            1055.0           676.0   28     61.89
# 2             932.0           594.0  270     40.27
# 3             932.0           594.0  365     41.05
# 4             978.4           825.5  360     44.30

# %% [markdown]
# So the first concrete sample has 540 cubic meter of cement, 0 cubic meter of blast furnace slag, 0 cubic meter of fly ash, 162 cubic meter of water, 2.5 cubic meter of superplaticizer, 1040 cubic meter of coarse aggregate, 676 cubic meter of fine aggregate. Such a concrete mix which is 28 days old, has a compressive strength of 79.99 MPa.

# %% [markdown]
# #### Let's check how many data points we have.

# %%
concrete_data.shape
# Out:
# (1030, 9)

# %% [markdown]
# So, there are approximately 1000 samples to train our model on. Because of the few samples, we have to be careful not to overfit the training data.

# %% [markdown]
# Let's check the dataset for any missing values.

# %%
concrete_data.describe()
# Out:
#             Cement  Blast Furnace Slag      Fly Ash        Water  \
# count  1030.000000         1030.000000  1030.000000  1030.000000
# mean    281.167864           73.895825    54.188350   181.567282
# std     104.506364           86.279342    63.997004    21.354219
# min     102.000000            0.000000     0.000000   121.800000
# 25%     192.375000            0.000000     0.000000   164.900000
# 50%     272.900000           22.000000     0.000000   185.000000
# 75%     350.000000          142.950000   118.300000   192.000000
# max     540.000000          359.400000   200.100000   247.000000
#
#        Superplasticizer  Coarse Aggregate  Fine Aggregate          Age  \
# count       1030.000000       1030.000000     1030.000000  1030.000000
# mean           6.204660        972.918932      773.580485    45.662136
# std            5.973841         77.753954       80.175980    63.169912
# min            0.000000        801.000000      594.000000     1.000000
# 25%            0.000000        932.000000      730.950000     7.000000
# 50%            6.400000        968.000000      779.500000    28.000000
# 75%           10.200000       1029.400000      824.000000    56.000000
# max           32.200000       1145.000000      992.600000   365.000000
#
#           Strength
# count  1030.000000
# mean     35.817961
# std      16.705742
# min       2.330000
# 25%      23.710000
# 50%      34.445000
# 75%      46.135000
# max      82.600000

# %%
concrete_data.isnull().sum()
# Out:
# Cement                0
# Blast Furnace Slag    0
# Fly Ash               0
# Water                 0
# Superplasticizer      0
# Coarse Aggregate      0
# Fine Aggregate        0
# Age                   0
# Strength              0
# dtype: int64

# %% [markdown]
# The data looks very clean and is ready to be used to build our model.

# %% [markdown]
# #### Split data into predictors and target

# %% [markdown]
# The target variable in this problem is the concrete sample strength. Therefore, our predictors will be all the other columns.

# %%
concrete_data_columns = concrete_data.columns

predictors = concrete_data[concrete_data_columns[concrete_data_columns != 'Strength']] # all columns except Strength
target = concrete_data['Strength'] # Strength column

# %% [markdown]
# <a id="item2"></a>

# %% [markdown]
# Let's do a quick sanity check of the predictors and the target dataframes.

# %%
predictors.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age
# 0            1040.0           676.0   28
# 1            1055.0           676.0   28
# 2             932.0           594.0  270
# 3             932.0           594.0  365
# 4             978.4           825.5  360

# %%
target.head()
# Out:
# 0    79.99
# 1    61.89
# 2    40.27
# 3    41.05
# 4    44.30
# Name: Strength, dtype: float64

# %% [markdown]
# Finally, the last step is to normalize the data by substracting the mean and dividing by the standard deviation.

# %%
predictors_norm = (predictors - predictors.mean()) / predictors.std()
predictors_norm.head()
# Out:
#      Cement  Blast Furnace Slag   Fly Ash     Water  Superplasticizer  \
# 0  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 1  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 2  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 3  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 4 -0.790075            0.678079 -0.846733  0.488555         -1.038638
#
#    Coarse Aggregate  Fine Aggregate       Age
# 0          0.862735       -1.217079 -0.279597
# 1          1.055651       -1.217079 -0.279597
# 2         -0.526262       -2.239829  3.551340
# 3         -0.526262       -2.239829  5.055221
# 4          0.070492        0.647569  4.976069

# %% [markdown]
# Let's save the number of predictors to *n_cols* since we will need this number when building our network.

# %%
n_cols = predictors_norm.shape[1] # number of predictors

# %% [markdown]
# <a id="item1"></a>

# %% [markdown]
# <a id='item32'></a>

# %% [markdown]
# ## Import Keras

# %% [markdown]
# Recall from the videos that Keras normally runs on top of a low-level library such as TensorFlow. This means that to be able to use the Keras library, you will have to install TensorFlow first and when you import the Keras library, it will be explicitly displayed what backend was used to install the Keras library. In CC Labs, we used TensorFlow as the backend to install Keras, so it should clearly print that when we import Keras.

# %% [markdown]
# #### Let's go ahead and import the Keras library

# %%
from tensorflow import keras

# %% [markdown]
# As you can see, the TensorFlow backend was used to install the Keras library.

# %% [markdown]
# Let's import the rest of the packages from the Keras library that we will need to build our regressoin model.

# %%
from keras.models import Sequential
from keras.layers import Dense

# %% [markdown]
# <a id='item33'></a>

# %% [markdown]
# ## Build a Neural Network

# %% [markdown]
# Let's define a function that defines our regression model for us so that we can conveniently call it to create our model.

# %%
# define regression model
def regression_model():
    # create model
    model = Sequential()
    model.add(Dense(50, activation='relu', input_shape=(n_cols,)))
    model.add(Dense(50, activation='relu'))
    #model.add(Dense(75, activation='relu'))
    model.add(Dense(1))

    # compile model
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %% [markdown]
# The above function create a model that has two hidden layers, each of 50 hidden units.

# %% [markdown]
# <a id="item4"></a>

# %% [markdown]
# <a id='item34'></a>

# %% [markdown]
# ## Train and Test the Network

# %% [markdown]
# Let's call the function now to create our model.

# %%
# build the model
model = regression_model()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# Now we will split our data into training and testing with a 70%-30% split (test_size=0.3).
#
# 70% of our data will be used for training :
#
# X_train : Our training data containing the variables the model will use to learn how to predict.
#
# y_train : Our training data containing the labels.
#
# #
# 30% of our data will be used for testing its performance metrics :
#
# X_test : Unseen data by the model, we will use it to make predictions with our trained model.
#
# y_test : The labels associated with X_test data, we will compare them with the predictions that our model provided as output when shown X_test and that way we will obtain performance metrics.

# %%
from sklearn.model_selection import train_test_split

# Split the dataset into training and test sets
X_train, X_test, y_train, y_test = train_test_split(predictors_norm, target, test_size=0.3, random_state=42)

# %% [markdown]
# Next, we will train the model using the *fit* method. We will train the model for 100 epochs.

# %%
# fit the model
model.fit(X_train, y_train, epochs=250, verbose=2)
# Out:
# Epoch 1/250
# 23/23 - 1s - 50ms/step - loss: 1534.8882
# Epoch 2/250
# 23/23 - 0s - 6ms/step - loss: 1396.1002
# Epoch 3/250
# 23/23 - 0s - 4ms/step - loss: 1176.1060
# Epoch 4/250
# 23/23 - 0s - 6ms/step - loss: 859.0472
# Epoch 5/250
# 23/23 - 0s - 6ms/step - loss: 529.1384
# Epoch 6/250
# 23/23 - 0s - 5ms/step - loss: 306.3107
# Epoch 7/250
# 23/23 - 0s - 7ms/step - loss: 228.9305
# Epoch 8/250
# 23/23 - 0s - 6ms/step - loss: 207.2316
# Epoch 9/250
# 23/23 - 0s - 13ms/step - loss: 197.5565
# Epoch 10/250
# 23/23 - 0s - 6ms/step - loss: 189.6881
# Epoch 11/250
# 23/23 - 0s - 6ms/step - loss: 183.1327
# Epoch 12/250
# 23/23 - 0s - 6ms/step - loss: 176.7470
# Epoch 13/250
# 23/23 - 0s - 6ms/step - loss: 171.8755
# Epoch 14/250
# 23/23 - 0s - 6ms/step - loss: 168.3011
# Epoch 15/250
# 23/23 - 0s - 6ms/step - loss: 163.8525
# Epoch 16/250
# 23/23 - 0s - 7ms/step - loss: 160.8951
# Epoch 17/250
# 23/23 - 0s - 6ms/step - loss: 157.5261
# Epoch 18/250
# 23/23 - 0s - 6ms/step - loss: 154.7699
# Epoch 19/250
# 23/23 - 0s - 7ms/step - loss: 151.5700
# Epoch 20/250
# 23/23 - 0s - 11ms/step - loss: 149.6048
# Epoch 21/250
# 23/23 - 0s - 6ms/step - loss: 146.8956
# Epoch 22/250
# 23/23 - 0s - 4ms/step - loss: 144.6033
# Epoch 23/250
# 23/23 - 0s - 6ms/step - loss: 143.7617
# Epoch 24/250
# 23/23 - 0s - 6ms/step - loss: 141.2459
# Epoch 25/250
# 23/23 - 0s - 6ms/step - loss: 139.0261
# Epoch 26/250
# 23/23 - 0s - 6ms/step - loss: 137.5058
# Epoch 27/250
# 23/23 - 0s - 6ms/step - loss: 135.8279
# Epoch 28/250
# 23/23 - 0s - 4ms/step - loss: 133.7799
# Epoch 29/250
# 23/23 - 0s - 6ms/step - loss: 132.1154
# Epoch 30/250
# 23/23 - 0s - 6ms/step - loss: 129.8046
# Epoch 31/250
# 23/23 - 0s - 6ms/step - loss: 128.5476
# Epoch 32/250
# 23/23 - 0s - 4ms/step - loss: 126.3306
# Epoch 33/250
# 23/23 - 0s - 4ms/step - loss: 124.6186
# Epoch 34/250
# 23/23 - 0s - 4ms/step - loss: 122.5623
# Epoch 35/250
# 23/23 - 0s - 6ms/step - loss: 121.1503
# Epoch 36/250
# 23/23 - 0s - 6ms/step - loss: 119.2892
# Epoch 37/250
# 23/23 - 0s - 4ms/step - loss: 117.0535
# Epoch 38/250
# 23/23 - 0s - 7ms/step - loss: 115.0575
# Epoch 39/250
# 23/23 - 0s - 4ms/step - loss: 114.3485
# Epoch 40/250
# 23/23 - 0s - 4ms/step - loss: 111.6089
# Epoch 41/250
# 23/23 - 0s - 6ms/step - loss: 109.0656
# Epoch 42/250
# 23/23 - 0s - 6ms/step - loss: 107.3132
# Epoch 43/250
# 23/23 - 0s - 6ms/step - loss: 105.4642
# Epoch 44/250
# 23/23 - 0s - 6ms/step - loss: 103.2169
# Epoch 45/250
# 23/23 - 0s - 6ms/step - loss: 101.9035
# Epoch 46/250
# 23/23 - 0s - 7ms/step - loss: 99.6083
# Epoch 47/250
# 23/23 - 0s - 6ms/step - loss: 97.7290
# Epoch 48/250
# 23/23 - 0s - 4ms/step - loss: 95.9029
# Epoch 49/250
# 23/23 - 0s - 6ms/step - loss: 93.4948
# Epoch 50/250
# 23/23 - 0s - 4ms/step - loss: 91.6526
# Epoch 51/250
# 23/23 - 0s - 6ms/step - loss: 89.1557
# Epoch 52/250
# 23/23 - 0s - 6ms/step - loss: 88.1339
# Epoch 53/250
# 23/23 - 0s - 6ms/step - loss: 85.5178
# Epoch 54/250
# 23/23 - 0s - 4ms/step - loss: 84.5044
# Epoch 55/250
# 23/23 - 0s - 6ms/step - loss: 81.4900
# Epoch 56/250
# 23/23 - 0s - 6ms/step - loss: 79.4212
# Epoch 57/250
# 23/23 - 0s - 3ms/step - loss: 77.8106
# Epoch 58/250
# 23/23 - 0s - 6ms/step - loss: 75.2132
# Epoch 59/250
# 23/23 - 0s - 6ms/step - loss: 73.5312
# Epoch 60/250
# 23/23 - 0s - 4ms/step - loss: 70.9863
# Epoch 61/250
# 23/23 - 0s - 3ms/step - loss: 69.6308
# Epoch 62/250
# 23/23 - 0s - 6ms/step - loss: 67.3884
# Epoch 63/250
# 23/23 - 0s - 4ms/step - loss: 66.3539
# Epoch 64/250
# 23/23 - 0s - 4ms/step - loss: 64.3121
# Epoch 65/250
# 23/23 - 0s - 6ms/step - loss: 62.7549
# Epoch 66/250
# 23/23 - 0s - 6ms/step - loss: 61.8531
# Epoch 67/250
# 23/23 - 0s - 6ms/step - loss: 60.8076
# Epoch 68/250
# 23/23 - 0s - 6ms/step - loss: 59.0938
# Epoch 69/250
# 23/23 - 0s - 6ms/step - loss: 57.8742
# Epoch 70/250
# 23/23 - 0s - 6ms/step - loss: 56.8219
# Epoch 71/250
# 23/23 - 0s - 6ms/step - loss: 55.5130
# Epoch 72/250
# 23/23 - 0s - 3ms/step - loss: 54.5065
# Epoch 73/250
# 23/23 - 0s - 6ms/step - loss: 53.5133
# Epoch 74/250
# 23/23 - 0s - 6ms/step - loss: 51.9674
# Epoch 75/250
# 23/23 - 0s - 6ms/step - loss: 51.0274
# Epoch 76/250
# 23/23 - 0s - 6ms/step - loss: 50.0609
# Epoch 77/250
# 23/23 - 0s - 3ms/step - loss: 49.2838
# Epoch 78/250
# 23/23 - 0s - 6ms/step - loss: 48.5341
# Epoch 79/250
# 23/23 - 0s - 6ms/step - loss: 47.4140
# Epoch 80/250
# 23/23 - 0s - 4ms/step - loss: 47.3727
# Epoch 81/250
# 23/23 - 0s - 4ms/step - loss: 46.0439
# Epoch 82/250
# 23/23 - 0s - 6ms/step - loss: 44.8250
# Epoch 83/250
# 23/23 - 0s - 4ms/step - loss: 44.6094
# Epoch 84/250
# 23/23 - 0s - 6ms/step - loss: 43.9938
# Epoch 85/250
# 23/23 - 0s - 4ms/step - loss: 42.7113
# Epoch 86/250
# 23/23 - 0s - 6ms/step - loss: 42.3469
# Epoch 87/250
# 23/23 - 0s - 4ms/step - loss: 41.6771
# Epoch 88/250
# 23/23 - 0s - 6ms/step - loss: 41.0801
# Epoch 89/250
# 23/23 - 0s - 7ms/step - loss: 40.6451
# Epoch 90/250
# 23/23 - 0s - 4ms/step - loss: 39.9134
# Epoch 91/250
# 23/23 - 0s - 6ms/step - loss: 39.2338
# Epoch 92/250
# 23/23 - 0s - 4ms/step - loss: 39.0537
# Epoch 93/250
# 23/23 - 0s - 6ms/step - loss: 38.1594
# Epoch 94/250
# 23/23 - 0s - 6ms/step - loss: 38.6095
# Epoch 95/250
# 23/23 - 0s - 4ms/step - loss: 37.4219
# Epoch 96/250
# 23/23 - 0s - 7ms/step - loss: 37.3608
# Epoch 97/250
# 23/23 - 0s - 6ms/step - loss: 36.7028
# Epoch 98/250
# 23/23 - 0s - 6ms/step - loss: 36.4938
# Epoch 99/250
# 23/23 - 0s - 6ms/step - loss: 36.4422
# Epoch 100/250
# 23/23 - 0s - 4ms/step - loss: 35.6639
# Epoch 101/250
# 23/23 - 0s - 7ms/step - loss: 35.4598
# Epoch 102/250
# 23/23 - 0s - 6ms/step - loss: 35.3954
# Epoch 103/250
# 23/23 - 0s - 6ms/step - loss: 34.6838
# Epoch 104/250
# 23/23 - 0s - 6ms/step - loss: 34.7228
# Epoch 105/250
# 23/23 - 0s - 6ms/step - loss: 33.7748
# Epoch 106/250
# 23/23 - 0s - 7ms/step - loss: 33.7126
# Epoch 107/250
# 23/23 - 0s - 6ms/step - loss: 32.8780
# Epoch 108/250
# 23/23 - 0s - 6ms/step - loss: 32.5376
# Epoch 109/250
# 23/23 - 0s - 7ms/step - loss: 32.5630
# Epoch 110/250
# 23/23 - 0s - 6ms/step - loss: 32.3473
# Epoch 111/250
# 23/23 - 0s - 7ms/step - loss: 31.9488
# Epoch 112/250
# 23/23 - 0s - 6ms/step - loss: 31.7416
# Epoch 113/250
# 23/23 - 0s - 6ms/step - loss: 31.2663
# Epoch 114/250
# 23/23 - 0s - 7ms/step - loss: 31.2203
# Epoch 115/250
# 23/23 - 0s - 6ms/step - loss: 31.3419
# Epoch 116/250
# 23/23 - 0s - 6ms/step - loss: 30.6070
# Epoch 117/250
# 23/23 - 0s - 4ms/step - loss: 30.3432
# Epoch 118/250
# 23/23 - 0s - 4ms/step - loss: 30.4270
# Epoch 119/250
# 23/23 - 0s - 6ms/step - loss: 29.8423
# Epoch 120/250
# 23/23 - 0s - 6ms/step - loss: 29.7346
# Epoch 121/250
# 23/23 - 0s - 3ms/step - loss: 29.8526
# Epoch 122/250
# 23/23 - 0s - 6ms/step - loss: 29.1872
# Epoch 123/250
# 23/23 - 0s - 3ms/step - loss: 29.5918
# Epoch 124/250
# 23/23 - 0s - 3ms/step - loss: 29.0873
# Epoch 125/250
# 23/23 - 0s - 3ms/step - loss: 28.8461
# Epoch 126/250
# 23/23 - 0s - 3ms/step - loss: 28.7565
# Epoch 127/250
# 23/23 - 0s - 6ms/step - loss: 28.6984
# Epoch 128/250
# 23/23 - 0s - 6ms/step - loss: 28.3659
# Epoch 129/250
# 23/23 - 0s - 6ms/step - loss: 28.0620
# Epoch 130/250
# 23/23 - 0s - 4ms/step - loss: 27.8573
# Epoch 131/250
# 23/23 - 0s - 6ms/step - loss: 27.9060
# Epoch 132/250
# 23/23 - 0s - 6ms/step - loss: 27.9533
# Epoch 133/250
# 23/23 - 0s - 4ms/step - loss: 27.9513
# Epoch 134/250
# 23/23 - 0s - 6ms/step - loss: 27.5916
# Epoch 135/250
# 23/23 - 0s - 6ms/step - loss: 27.3860
# Epoch 136/250
# 23/23 - 0s - 6ms/step - loss: 27.7585
# Epoch 137/250
# 23/23 - 0s - 4ms/step - loss: 27.0958
# Epoch 138/250
# 23/23 - 0s - 6ms/step - loss: 26.8132
# Epoch 139/250
# 23/23 - 0s - 6ms/step - loss: 27.8199
# Epoch 140/250
# 23/23 - 0s - 6ms/step - loss: 27.5770
# Epoch 141/250
# 23/23 - 0s - 6ms/step - loss: 26.4630
# Epoch 142/250
# 23/23 - 0s - 6ms/step - loss: 26.9156
# Epoch 143/250
# 23/23 - 0s - 7ms/step - loss: 26.1313
# Epoch 144/250
# 23/23 - 0s - 5ms/step - loss: 26.1073
# Epoch 145/250
# 23/23 - 0s - 6ms/step - loss: 26.5998
# Epoch 146/250
# 23/23 - 0s - 6ms/step - loss: 26.8440
# Epoch 147/250
# 23/23 - 0s - 6ms/step - loss: 26.1916
# Epoch 148/250
# 23/23 - 0s - 7ms/step - loss: 25.5915
# Epoch 149/250
# 23/23 - 0s - 6ms/step - loss: 25.7706
# Epoch 150/250
# 23/23 - 0s - 6ms/step - loss: 25.4004
# Epoch 151/250
# 23/23 - 0s - 4ms/step - loss: 25.8943
# Epoch 152/250
# 23/23 - 0s - 6ms/step - loss: 26.1818
# Epoch 153/250
# 23/23 - 0s - 6ms/step - loss: 25.2662
# Epoch 154/250
# 23/23 - 0s - 6ms/step - loss: 25.1770
# Epoch 155/250
# 23/23 - 0s - 4ms/step - loss: 25.1959
# Epoch 156/250
# 23/23 - 0s - 6ms/step - loss: 25.1172
# Epoch 157/250
# 23/23 - 0s - 6ms/step - loss: 25.0243
# Epoch 158/250
# 23/23 - 0s - 7ms/step - loss: 24.9828
# Epoch 159/250
# 23/23 - 0s - 6ms/step - loss: 24.7635
# Epoch 160/250
# 23/23 - 0s - 3ms/step - loss: 24.6074
# Epoch 161/250
# 23/23 - 0s - 6ms/step - loss: 24.3541
# Epoch 162/250
# 23/23 - 0s - 6ms/step - loss: 24.7723
# Epoch 163/250
# 23/23 - 0s - 6ms/step - loss: 24.5715
# Epoch 164/250
# 23/23 - 0s - 6ms/step - loss: 25.2745
# Epoch 165/250
# 23/23 - 0s - 6ms/step - loss: 24.6202
# Epoch 166/250
# 23/23 - 0s - 6ms/step - loss: 24.2112
# Epoch 167/250
# 23/23 - 0s - 6ms/step - loss: 24.0674
# Epoch 168/250
# 23/23 - 0s - 4ms/step - loss: 24.3488
# Epoch 169/250
# 23/23 - 0s - 4ms/step - loss: 24.4716
# Epoch 170/250
# 23/23 - 0s - 6ms/step - loss: 24.2034
# Epoch 171/250
# 23/23 - 0s - 4ms/step - loss: 23.8640
# Epoch 172/250
# 23/23 - 0s - 6ms/step - loss: 24.0078
# Epoch 173/250
# 23/23 - 0s - 7ms/step - loss: 23.6983
# Epoch 174/250
# 23/23 - 0s - 6ms/step - loss: 23.7080
# Epoch 175/250
# 23/23 - 0s - 6ms/step - loss: 23.5216
# Epoch 176/250
# 23/23 - 0s - 4ms/step - loss: 23.3270
# Epoch 177/250
# 23/23 - 0s - 6ms/step - loss: 23.3226
# Epoch 178/250
# 23/23 - 0s - 6ms/step - loss: 23.1661
# Epoch 179/250
# 23/23 - 0s - 6ms/step - loss: 23.3894
# Epoch 180/250
# 23/23 - 0s - 4ms/step - loss: 22.7249
# Epoch 181/250
# 23/23 - 0s - 6ms/step - loss: 23.2402
# Epoch 182/250
# 23/23 - 0s - 4ms/step - loss: 22.6093
# Epoch 183/250
# 23/23 - 0s - 5ms/step - loss: 23.0606
# Epoch 184/250
# 23/23 - 0s - 6ms/step - loss: 23.2708
# Epoch 185/250
# 23/23 - 0s - 6ms/step - loss: 22.6256
# Epoch 186/250
# 23/23 - 0s - 4ms/step - loss: 23.3431
# Epoch 187/250
# 23/23 - 0s - 7ms/step - loss: 22.4052
# Epoch 188/250
# 23/23 - 0s - 6ms/step - loss: 22.4648
# Epoch 189/250
# 23/23 - 0s - 6ms/step - loss: 22.4184
# Epoch 190/250
# 23/23 - 0s - 6ms/step - loss: 22.1829
# Epoch 191/250
# 23/23 - 0s - 6ms/step - loss: 22.0657
# Epoch 192/250
# 23/23 - 0s - 4ms/step - loss: 22.0210
# Epoch 193/250
# 23/23 - 0s - 6ms/step - loss: 22.2002
# Epoch 194/250
# 23/23 - 0s - 7ms/step - loss: 22.0957
# Epoch 195/250
# 23/23 - 0s - 7ms/step - loss: 22.1901
# Epoch 196/250
# 23/23 - 0s - 6ms/step - loss: 21.9960
# Epoch 197/250
# 23/23 - 0s - 6ms/step - loss: 21.5394
# Epoch 198/250
# 23/23 - 0s - 6ms/step - loss: 21.7178
# Epoch 199/250
# 23/23 - 0s - 6ms/step - loss: 22.0139
# Epoch 200/250
# 23/23 - 0s - 6ms/step - loss: 21.7558
# Epoch 201/250
# 23/23 - 0s - 6ms/step - loss: 21.6842
# Epoch 202/250
# 23/23 - 0s - 5ms/step - loss: 21.3621
# Epoch 203/250
# 23/23 - 0s - 6ms/step - loss: 21.9291
# Epoch 204/250
# 23/23 - 0s - 7ms/step - loss: 21.2726
# Epoch 205/250
# 23/23 - 0s - 7ms/step - loss: 21.1069
# Epoch 206/250
# 23/23 - 0s - 6ms/step - loss: 21.2039
# Epoch 207/250
# 23/23 - 0s - 6ms/step - loss: 21.0257
# Epoch 208/250
# 23/23 - 0s - 7ms/step - loss: 20.8490
# Epoch 209/250
# 23/23 - 0s - 6ms/step - loss: 20.8131
# Epoch 210/250
# 23/23 - 0s - 6ms/step - loss: 20.9324
# Epoch 211/250
# 23/23 - 0s - 4ms/step - loss: 20.5694
# Epoch 212/250
# 23/23 - 0s - 7ms/step - loss: 21.1729
# Epoch 213/250
# 23/23 - 0s - 4ms/step - loss: 20.7532
# Epoch 214/250
# 23/23 - 0s - 3ms/step - loss: 20.9047
# Epoch 215/250
# 23/23 - 0s - 6ms/step - loss: 20.6433
# Epoch 216/250
# 23/23 - 0s - 4ms/step - loss: 20.9744
# Epoch 217/250
# 23/23 - 0s - 6ms/step - loss: 20.5880
# Epoch 218/250
# 23/23 - 0s - 6ms/step - loss: 20.3277
# Epoch 219/250
# 23/23 - 0s - 6ms/step - loss: 20.3882
# Epoch 220/250
# 23/23 - 0s - 7ms/step - loss: 20.5105
# Epoch 221/250
# 23/23 - 0s - 6ms/step - loss: 20.0496
# Epoch 222/250
# 23/23 - 0s - 6ms/step - loss: 19.9528
# Epoch 223/250
# 23/23 - 0s - 4ms/step - loss: 19.9912
# Epoch 224/250
# 23/23 - 0s - 6ms/step - loss: 20.2807
# Epoch 225/250
# 23/23 - 0s - 6ms/step - loss: 20.1161
# Epoch 226/250
# 23/23 - 0s - 4ms/step - loss: 19.7579
# Epoch 227/250
# 23/23 - 0s - 6ms/step - loss: 19.8115
# Epoch 228/250
# 23/23 - 0s - 7ms/step - loss: 19.9592
# Epoch 229/250
# 23/23 - 0s - 5ms/step - loss: 19.5484
# Epoch 230/250
# 23/23 - 0s - 4ms/step - loss: 19.8870
# Epoch 231/250
# 23/23 - 0s - 4ms/step - loss: 19.6109
# Epoch 232/250
# 23/23 - 0s - 6ms/step - loss: 19.4201
# Epoch 233/250
# 23/23 - 0s - 4ms/step - loss: 19.2967
# Epoch 234/250
# 23/23 - 0s - 6ms/step - loss: 19.2845
# Epoch 235/250
# 23/23 - 0s - 4ms/step - loss: 19.1152
# Epoch 236/250
# 23/23 - 0s - 6ms/step - loss: 19.1332
# Epoch 237/250
# 23/23 - 0s - 8ms/step - loss: 19.3708
# Epoch 238/250
# 23/23 - 0s - 5ms/step - loss: 19.2961
# Epoch 239/250
# 23/23 - 0s - 6ms/step - loss: 19.0050
# Epoch 240/250
# 23/23 - 0s - 4ms/step - loss: 19.2804
# Epoch 241/250
# 23/23 - 0s - 3ms/step - loss: 19.4035
# Epoch 242/250
# 23/23 - 0s - 4ms/step - loss: 19.3523
# Epoch 243/250
# 23/23 - 0s - 4ms/step - loss: 19.6423
# Epoch 244/250
# 23/23 - 0s - 6ms/step - loss: 19.2230
# Epoch 245/250
# 23/23 - 0s - 4ms/step - loss: 18.9835
# Epoch 246/250
# 23/23 - 0s - 7ms/step - loss: 19.2190
# Epoch 247/250
# 23/23 - 0s - 6ms/step - loss: 18.6673
# Epoch 248/250
# 23/23 - 0s - 4ms/step - loss: 18.8632
# Epoch 249/250
# 23/23 - 0s - 4ms/step - loss: 18.6866
# Epoch 250/250
# 23/23 - 0s - 6ms/step - loss: 18.5476

# %% [markdown]
# ### Now lets evaluate our model and get performance metrics !
#
# First, since our model only saw the training data and learned from it, we will make predictions on the unseen test set.
#
# y_pred are the predictions that our model generated from it's experience when shown the predictor variables of X_test.
#
# That way we can compare y_pred (predictions made by our model) with y_test (the real labels of X_test) and see the difference as performance metrics.

# %%
# Make predictions on the test set
y_pred = model.predict(X_test)
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step

# %% [markdown]
# Since this is a regression model we will be using mean squared error, mean absolute error and the r squared score to evaluate it.

# %%
# Calculate and print regression metrics
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f'Mean Squared Error (MSE): {mse:.4f}')
print(f'Mean Absolute Error (MAE): {mae:.4f}')
print(f'R² Score: {r2:.4f}')
# Out:
# Mean Squared Error (MSE): 30.0687
# Mean Absolute Error (MAE): 4.1821
# R² Score: 0.8889

# %% [markdown]
# Feel free to vary the following and note what impact each change has on the model's performance:
#
# 1. Increase or decreate number of neurons in hidden layers
# 2. Add more hidden layers
# 3. Increase number of epochs

# %% [markdown]
# For other models, other types of performance metrics are more meaningfull. It all depends on context and the end goal of the model.
#
# Research, planning and analysing various metrics with a clearly defined end goal is key to understanding how capable a model is and what are his limitations.
#
# Keep that in mind when tackling the next exercises!

# %% [markdown]
# ### Thank you for following this tutorial!
